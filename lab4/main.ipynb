# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
_data = pd.read_excel('medical_2.xlsx')
_data.head(20)
# Out:
#     День  Рівень цукру (мг/дл)
# 0      1             99.646696
# 1      2             99.307489
# 2      3            111.026659
# 3      4             87.724961
# 4      5             86.802996
# 5      6            105.838461
# 6      7            114.879603
# 7      8            103.982052
# 8      9            100.783950
# 9     10             79.861641
# 10    11            114.226282
# 11    12            108.064453
# 12    13            100.420242
# 13    14             82.199509
# 14    15            105.650520
# 15    16             84.280581
# 16    17            112.622542
# 17    18             85.683946
# 18    19            104.300847
# 19    20            135.008840

# %%
_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   День                  100 non-null    int64
#  1   Рівень цукру (мг/дл)  100 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
plt.figure(figsize=(10, 5))
plt.title('Лінійна діаграма')
plt.plot(_data['День'], _data['Рівень цукру (мг/дл)'])
plt.grid()
plt.xlabel('День')
plt.ylabel('Рівень цукру (мг/дл)')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title('Стовпчикова діаграма')
plt.bar(_data['День'], _data['Рівень цукру (мг/дл)'])
plt.grid()
plt.xlabel('День')
plt.ylabel('Рівень цукру (мг/дл)')
plt.show()

# %%
_1data=_data.iloc[0:24]
_2data=_data.iloc[25:51]
_3data=_data.iloc[52:77]
_4data=_data.iloc[78:99]

plt.figure(figsize=(12, 6))
plt.title('Кругова діаграма')
plt.pie(_1data['Рівень цукру (мг/дл)'], labels=_1data['День'], autopct='%1.1f%%')
plt.show()

plt.figure(figsize=(12, 6))
plt.title('Кругова діаграма')
plt.pie(_2data['Рівень цукру (мг/дл)'], labels=_2data['День'], autopct='%1.1f%%')
plt.show()

plt.figure(figsize=(12, 6))
plt.title('Кругова діаграма')
plt.pie(_3data['Рівень цукру (мг/дл)'], labels=_3data['День'], autopct='%1.1f%%')
plt.show()

plt.figure(figsize=(12, 6))
plt.title('Кругова діаграма')
plt.pie(_4data['Рівень цукру (мг/дл)'], labels=_4data['День'], autopct='%1.1f%%')
plt.show()

# %%
x = np.arange(0, 100, 1)

def funct(x):
    return pow(np.exp(x),(1/(x+1)))

y = funct(x)

plt.figure(figsize=(10, 5))
plt.title('Графік функції')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, y)
