# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
excel_file = pd.ExcelFile('medical_2.xlsx')
sheet_names = excel_file.sheet_names
print(f"{sheet_names}")
# Out:
# ['Глюкоза', 'Захворювання', 'Вікові групи']

# %%
_data_glucose = pd.read_excel('medical_2.xlsx', sheet_name='Глюкоза')
_data_glucose.head(20)
# Out:
#     День  Рівень цукру (мг/дл)
# 0      1             99.646696
# 1      2             99.307489
# 2      3            111.026659
# 3      4             87.724961
# 4      5             86.802996
# 5      6            105.838461
# 6      7            114.879603
# 7      8            103.982052
# 8      9            100.783950
# 9     10             79.861641
# 10    11            114.226282
# 11    12            108.064453
# 12    13            100.420242
# 13    14             82.199509
# 14    15            105.650520
# 15    16             84.280581
# 16    17            112.622542
# 17    18             85.683946
# 18    19            104.300847
# 19    20            135.008840

# %%
_data_sick = pd.read_excel('medical_2.xlsx', sheet_name='Захворювання')
_data_sick.head()
# Out:
#   Захворювання  Кількість пацієнтів
# 0       Діабет                  159
# 1   Гіпертонія                  133
# 2     Ожиріння                  124
# 3   Холестерин                  136
# 4        Астма                   91

# %%
_data_age = pd.read_excel('medical_2.xlsx', sheet_name='Вікові групи')
_data_age.head()
# Out:
#   Вікова група  Кількість пацієнтів
# 0          <18                  634
# 1        18-30                  390
# 2        30-50                  507
# 3        50-60                  419
# 4        60-70                  569

# %%
plt.figure(figsize=(10, 5))
plt.title('Лінійна діаграма')
plt.plot(_data['День'], _data['Рівень цукру (мг/дл)'])
plt.grid()
plt.xlabel('День')
plt.ylabel('Рівень цукру (мг/дл)')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title('Стовпчикова діаграма')
plt.bar(_data_sick['Захворювання'], _data_sick['Кількість пацієнтів'])
plt.grid()
plt.xlabel('День')
plt.ylabel('Рівень цукру (мг/дл)')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.title('Кругова діаграма')
plt.pie(_data_age['Кількість пацієнтів'], labels=_data_age['Вікова група'], autopct='%1.1f%%')
plt.show()

# %%
x = np.arange(0, 100, 1)

def funct(x):
    return pow(np.exp(x),(1/(x+1)))

y = funct(x)

plt.figure(figsize=(10, 5))
plt.title('Графік функції')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, y)
